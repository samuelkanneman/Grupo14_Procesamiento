# %%
# Importar bibliotecas necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import heapq

# %%
# Cargar archivos CSV
precios_hoteles = pd.read_csv('valenciahoteles.csv', encoding='latin-1')

# %%
# Se visualiza el número de registros y variables
precios_hoteles.shape
# Out:
# (3959, 10)

# %%
precios_hoteles.head(10)
# Out:
#                        Nombre                      Distrito  Valoración  \
# 0              HOSTAL ABASTOS           Extramurs, Valencia         7.9
# 1                   BIZZBEACH  Poblados marítimos, Valencia         8.0
# 2  HOSTAL ON DORMIRE VALENCIA     Quatre Carreres, Valencia         7.4
# 3                ZALAMERA BNB           Extramurs, Valencia         8.8
# 4          SWEET HOTEL RENASA     El Pla del Real, Valencia         8.1
# 5            PENSIÓN ALICANTE        Ciutat Vella, Valencia         8.2
# 6                 HOTEL TURIA            Campanar, Valencia         7.5
# 7         HI VALENCIA CANOVAS            Eixample, Valencia         7.9
# 8               B&B EL MERCAT        Ciutat Vella, Valencia         6.5
# 9     SWEET HOTEL CONTINENTAL        Ciutat Vella, Valencia         8.1
#
#    Número de comentarios  Precio       Fecha  \
# 0                    767    38.0  2022-07-31
# 1                    206    37.0  2022-07-31
# 2                   1458    27.5  2022-07-31
# 3                   1009    79.0  2022-07-31
# 4                   3441    84.0  2022-07-31
# 5                   1940    33.0  2022-07-31
# 6                   3045    97.0  2022-07-31
# 7                   2214    67.5  2022-07-31
# 8                    518    75.0  2022-07-31
# 9                   3174    86.5  2022-07-31
#
#                                            Dirección     CP        lat  \
# 0                  CALLE DE ALBERIQUE, 19, Valencia   46008  39.466484
# 1                      CALLE DE IBIZA, 17, Valencia   46024  39.460211
# 2                 CALLE DE RUBEN VELA, 23, Valencia   46006  39.455528
# 3         CALLE DE PELAYO, 44, LA ROQUETA, Valencia   46007  39.465586
# 4                  AVENIDA DE CATALUÑA, 5, Valencia   46010  39.480567
# 5                      CALLE DE RIBERA, 2, Valencia   46002  39.468880
# 6  CARRER DEL PROFESOR BELTRÁN BÁGUENA, 2, Valencia   46009  39.480357
# 7              CALLE DE CIRILO AMORÓS, 82, Valencia   46004  39.466706
# 8            CARRER DEL PEU DE LA CREU, 5, Valencia   46001  39.473021
# 9                     CALLE DE CORREOS, 8, Valencia   46002  39.469706
#
#        long
# 0 -0.388092
# 1 -0.339943
# 2 -0.374437
# 3 -0.379132
# 4 -0.352960
# 5 -0.375860
# 6 -0.389011
# 7 -0.372928
# 8 -0.380425
# 9 -0.374548

# %%
# Se visualizan 3 registros aleatorios con sus respectivas variables
precios_hoteles.sample(5)
# Out:
#                                          Nombre                   Distrito  \
# 333                  MARQUÉS HOUSE HOTEL 4* SUP     Ciutat Vella, Valencia
# 3092                            PRIMUS VALENCIA   Camins al Grau, Valencia
# 1070                 HOSTAL ON DORMIRE VALENCIA  Quatre Carreres, Valencia
# 1926  PALACIO SANTA CLARA, AUTOGRAPH COLLECTION     Ciutat Vella, Valencia
# 2556               CENTER VALENCIA YOUTH HOSTEL     Ciutat Vella, Valencia
#
#       Valoración  Número de comentarios  Precio       Fecha  \
# 333          9.2                   1101   164.5  2022-12-18
# 3092         8.2                   3805   186.5  2022-09-11
# 1070         7.4                   1455    25.5  2022-11-27
# 1926         9.3                    263   222.5  2023-01-22
# 2556         8.0                   2102   125.0  2022-09-05
#
#                                             Dirección     CP        lat  \
# 333   CALLE DE LA ABADÍA DE SAN MARTÍN, 10, Valencia   46002  39.473000
# 3092                  CALLE DE MENORCA, 22, Valencia   46023  39.457691
# 1070               CALLE DE RUBEN VELA, 23, Valencia   46006  39.455528
# 1926          CALLE DE PASCUAL Y GENIS, 22, Valencia   46002  39.468230
# 2556                CALLE DE SAMANIEGO, 18, Valencia   46003  39.477649
#
#           long
# 333  -0.375400
# 3092 -0.345728
# 1070 -0.374437
# 1926 -0.373852
# 2556 -0.376240

# %%
# Se visualiza que algunas variables como fecha, CP, lat y long tienen su formato mal definido
precios_hoteles.dtypes
# Out:
# Nombre                    object
# Distrito                  object
# Valoración               float64
# Número de comentarios      int64
# Precio                   float64
# Fecha                     object
# Dirección                 object
# CP                         int64
# lat                      float64
# long                     float64
# dtype: object

# %%
precios_hoteles['Fecha']  = pd.to_datetime(precios_hoteles['Fecha'],)

# %%
precios_hoteles['CP'] = precios_hoteles['CP'].astype('object')
precios_hoteles['lat'] = precios_hoteles['lat'].astype('object')
precios_hoteles['long'] = precios_hoteles['long'].astype('object')

# %%
precios_hoteles.dtypes
# Out:
# Nombre                           object
# Distrito                         object
# Valoración                      float64
# Número de comentarios             int64
# Precio                          float64
# Fecha                    datetime64[ns]
# Dirección                        object
# CP                               object
# lat                              object
# long                             object
# dtype: object

# %%
# Se transforma la columna "Fecha" a formato datetime64[ns]
precios_hoteles['Fecha']  = pd.to_datetime(precios_hoteles['Fecha'],)

# Se transforman las variables CP, lat y long a OBJECT

precios_hoteles['CP'] = precios_hoteles['CP'].astype('object')
precios_hoteles['lat'] = precios_hoteles['lat'].astype('object')
precios_hoteles['long'] = precios_hoteles['long'].astype('object')

# %%
precios_hoteles.dtypes
# Out:
# Nombre                           object
# Distrito                         object
# Valoración                      float64
# Número de comentarios             int64
# Precio                          float64
# Fecha                    datetime64[ns]
# Dirección                        object
# CP                               object
# lat                              object
# long                             object
# dtype: object

# %%
# Estadísticas descriptivas del DataFrame resultante
precios_hoteles.describe()
# Out:
#         Valoración  Número de comentarios       Precio
# count  3959.000000            3959.000000  3959.000000
# mean      8.316292            2193.210154   140.196262
# std       0.616531            2021.854114    84.133629
# min       5.700000              12.000000    20.000000
# 25%       8.000000            1006.000000    84.000000
# 50%       8.400000            1666.000000   122.000000
# 75%       8.700000            2629.000000   169.000000
# max       9.500000           12713.000000   855.000000

# %%
# Análisis por Distrito: Cantidad de distritos
num_distritos = precios_hoteles['Distrito'].nunique()

print("En este Datasets se presentan los siguientes %d distritos:" %num_distritos)
distritos = precios_hoteles['Distrito'].unique()
distritos_df = pd.DataFrame(distritos)
print(distritos_df)
# Out:
# En este Datasets se presentan los siguientes 13 distritos:
#                                0
# 0            Extramurs, Valencia
# 1   Poblados marítimos, Valencia
# 2      Quatre Carreres, Valencia
# 3      El Pla del Real, Valencia
# 4         Ciutat Vella, Valencia
# 5             Campanar, Valencia
# 6             Eixample, Valencia
# 7       Camins al Grau, Valencia
# 8            Benicalap, Valencia
# 9   Poblados del Oeste, Valencia
# 10          Benimaclet, Valencia
# 11             Algirós, Valencia
# 12           La Saïdia, Valencia

# %%
# Análisis por Distrito: Cantidad de Hoteles por distrito
plt.figure()
precios_hoteles['Distrito'].value_counts()
# Out:
# Ciutat Vella, Valencia          1440
# Camins al Grau, Valencia         607
# Poblados marítimos, Valencia     415
# Eixample, Valencia               408
# Quatre Carreres, Valencia        304
# Extramurs, Valencia              211
# Benicalap, Valencia              157
# Campanar, Valencia               126
# Poblados del Oeste, Valencia     126
# El Pla del Real, Valencia        114
# Benimaclet, Valencia              38
# Algirós, Valencia                  8
# La Saïdia, Valencia                5
# Name: Distrito, dtype: int64

# %%
#Grafica un histograma con la cantidad de hoteles por districto
precios_hoteles['Distrito'].value_counts().plot.hist(title='Cantidad de Hoteles por Distrito')
plt.xlabel('Cantidad', color='grey')
plt.ylabel('Districto', color='grey')
plt.yticks(range(len(precios_hoteles['Distrito'].value_counts())), precios_hoteles['Distrito'].value_counts().index)
# Out:
# ([<matplotlib.axis.YTick at 0x26bd2bd6fa0>,
#   <matplotlib.axis.YTick at 0x26bd2bd6d30>,
#   <matplotlib.axis.YTick at 0x26bd2bd61f0>,
#   <matplotlib.axis.YTick at 0x26bd2c6a340>,
#   <matplotlib.axis.YTick at 0x26bd2c6aa90>,
#   <matplotlib.axis.YTick at 0x26bd2c6aaf0>,
#   <matplotlib.axis.YTick at 0x26bd2c63820>,
#   <matplotlib.axis.YTick at 0x26bd2c74070>,
#   <matplotlib.axis.YTick at 0x26bd2c74730>,
#   <matplotlib.axis.YTick at 0x26bd2c74e80>,
#   <matplotlib.axis.YTick at 0x26bd2c79790>,
#   <matplotlib.axis.YTick at 0x26bd2c79d90>,
#   <matplotlib.axis.YTick at 0x26bd2c79580>],
#  [Text(0, 0, 'Ciutat Vella, Valencia'),
#   Text(0, 1, 'Camins al Grau, Valencia'),
#   Text(0, 2, 'Poblados marítimos, Valencia'),
#   Text(0, 3, 'Eixample, Valencia'),
#   Text(0, 4, 'Quatre Carreres, Valencia'),
#   Text(0, 5, 'Extramurs, Valencia'),
#   Text(0, 6, 'Benicalap, Valencia'),
#   Text(0, 7, 'Campanar, Valencia'),
#   Text(0, 8, 'Poblados del Oeste, Valencia'),
#   Text(0, 9, 'El Pla del Real, Valencia'),
#   Text(0, 10, 'Benimaclet, Valencia'),
#   Text(0, 11, 'Algirós, Valencia'),
#   Text(0, 12, 'La Saïdia, Valencia')])

# %%
# Promedio de valoraciones según distrito

columnas_eliminar = ['Número de comentarios','Precio']

prom_distritos = precios_hoteles.groupby(by='Distrito').mean('Valoración').round(decimals=1).rename(columns={'Valoración': 'Promedio de Valoración'}).drop(columnas_eliminar, axis=1)
prom_distritos.sort_values('Promedio de Valoración', ascending=False)
# Out:
#                               Promedio de Valoración
# Distrito
# Eixample, Valencia                               8.6
# Benimaclet, Valencia                             8.5
# Ciutat Vella, Valencia                           8.5
# Extramurs, Valencia                              8.4
# Camins al Grau, Valencia                         8.3
# El Pla del Real, Valencia                        8.3
# Benicalap, Valencia                              8.2
# Poblados del Oeste, Valencia                     8.2
# Poblados marítimos, Valencia                     8.1
# Campanar, Valencia                               8.0
# Algirós, Valencia                                7.9
# Quatre Carreres, Valencia                        7.9
# La Saïdia, Valencia                              6.4

# %%
prom_distritos.plot.barh(color="red")#Grafico Promedio de valoraciones según distrito
# Out:
# <AxesSubplot:ylabel='Distrito'>

# %%
# Análisis por Hotel: Cantidad de hoteles
num_hoteles = precios_hoteles['Nombre'].nunique()

print("En este Datasets se presentan los siguientes %d hoteles:" %num_hoteles)
hoteles = precios_hoteles['Nombre'].unique()
hoteles_df = pd.DataFrame(hoteles)
print(hoteles_df)
# Out:
# En este Datasets se presentan los siguientes 154 hoteles:
#                               0
# 0                HOSTAL ABASTOS
# 1                     BIZZBEACH
# 2    HOSTAL ON DORMIRE VALENCIA
# 3                  ZALAMERA BNB
# 4            SWEET HOTEL RENASA
# ..                          ...
# 149  PLAZA REDONDA BRUGADA HOME
# 150        DORMAVALENCIA HOSTEL
# 151            THE RIVER HOSTEL
# 152          UP HOSTEL VALENCIA
# 153             CANTAGUA HOSTEL
#
# [154 rows x 1 columns]

# %%
qa_hoteles = precios_hoteles['Nombre'].value_counts()
qa_hoteles = pd.DataFrame(qa_hoteles)
qa_hoteles.rename(columns={'Nombre': 'Cantidad'})
# Out:
#                                Cantidad
# THE WESTIN VALENCIA                  43
# AC HOTEL VALENCIA BY MARRIOTT        43
# HOTEL TURIA                          43
# SERCOTEL SOROLLA PALACE              43
# ILUNION AQUA 4                       43
# ...                                 ...
# SUITES BY ERIC OLSAN (PESET)          1
# DORMAVALENCIA HOSTEL                  1
# THE RIVER HOSTEL                      1
# UP HOSTEL VALENCIA                    1
# CANTAGUA HOSTEL                       1
#
# [154 rows x 1 columns]

# %%
q_hoteles_may = precios_hoteles['Nombre'].value_counts().head(10)
q_hoteles_may = pd.DataFrame(q_hoteles_may)
q_hoteles_may.rename(columns={'Nombre': 'Cantidad'})
# Out:
#                                                     Cantidad
# THE WESTIN VALENCIA                                       43
# AC HOTEL VALENCIA BY MARRIOTT                             43
# HOTEL TURIA                                               43
# SERCOTEL SOROLLA PALACE                                   43
# ILUNION AQUA 4                                            43
# HOTEL MALCOM AND BARRET                                   43
# PALACIO VALLIER 5*                                        42
# HOLIDAY INN EXPRESS CIUDAD DE LAS CIENCIAS, AN ...        42
# ILUNION AQUA 3                                            42
# HOSPES PALAU DE LA MAR                                    42

# %%
q_hoteles_men = precios_hoteles['Nombre'].value_counts().tail(10)
q_hoteles_men
# Out:
# PENSIÓN MORATIN                                                                        3
# PLAZA REDONDA BRUGADA HOME                                                             3
# PENSIÓN UNIVERSAL                                                                      2
# VALENCIA SUITS YOU INN -ADULTS ONLY ROOMS, REMOTE CHECK IN, BIKE & E-SCOOTER RENTAL    2
# FETÉN                                                                                  1
# SUITES BY ERIC OLSAN (PESET)                                                           1
# DORMAVALENCIA HOSTEL                                                                   1
# THE RIVER HOSTEL                                                                       1
# UP HOSTEL VALENCIA                                                                     1
# CANTAGUA HOSTEL                                                                        1
# Name: Nombre, dtype: int64

# %%
# Promedio de valoraciones en los mejores 5 hoteles

columnas_eliminar = ['Número de comentarios','Precio']

prom_hoteles = precios_hoteles.groupby(by='Nombre').mean('Valoración').round(decimals=1).rename(columns={'Valoración': 'Promedio de Valoración'}).drop(columnas_eliminar, axis=1).sort_values('Promedio de Valoración', ascending=False).head(5)
prom_hoteles
# Out:
#                       Promedio de Valoración
# Nombre
# PALACIO VALLIER 5*                       9.5
# HOTEL 19-30 VALENCIA                     9.4
# FETÉN                                    9.4
# L'ESPLAI VALENCIA                        9.4
# YOURS BOUTIQUE STAY                      9.3

# %%
# Promedio de valoraciones en los peores 5 hoteles

columnas_eliminar = ['Número de comentarios','Precio']

prom_peores_hoteles = precios_hoteles.groupby(by='Nombre').mean('Valoración').round(decimals=1).rename(columns={'Valoración': 'Promedio de Valoración'}).drop(columnas_eliminar, axis=1).sort_values('Promedio de Valoración').head(5)
prom_peores_hoteles
# Out:
#                             Promedio de Valoración
# Nombre
# MALVARROSA BEACH ROOMS                         5.7
# RUZAFA ROOMS                                   6.0
# THE TOWERS OF SERRANO HOME                     6.2
# B&B EL MERCAT                                  6.5
# PENSIÓN MORATIN                                6.8

# %%
Eixample = precios_hoteles[precios_hoteles['Distrito']== 'Eixample, Valencia']
Eixample
# Out:
#                                    Nombre            Distrito  Valoración  \
# 7                     HI VALENCIA CANOVAS  Eixample, Valencia         7.9
# 33                      ONE SHOT COLÓN 46  Eixample, Valencia         8.5
# 40                            HOTEL DIMAR  Eixample, Valencia         8.6
# 58           SENATOR PARQUE CENTRAL HOTEL  Eixample, Valencia         8.0
# 73                 HOSPES PALAU DE LA MAR  Eixample, Valencia         8.6
# ...                                   ...                 ...         ...
# 3904  AC HOTEL COLÓN VALENCIA BY MARRIOTT  Eixample, Valencia         8.5
# 3905                 RUSSAFA YOUTH HOSTEL  Eixample, Valencia         8.4
# 3925         NH COLLECTION COLÓN VALENCIA  Eixample, Valencia         8.7
# 3936           MD MODERN HOTEL - JARDINES  Eixample, Valencia         8.5
# 3940                  YOURS BOUTIQUE STAY  Eixample, Valencia         9.3
#
#       Número de comentarios  Precio      Fecha  \
# 7                      2214    67.5 2022-07-31
# 33                     1556   137.0 2022-07-31
# 40                     2111   130.0 2022-07-31
# 58                     3580    97.0 2022-07-31
# 73                     1145   193.5 2022-07-31
# ...                     ...     ...        ...
# 3904                    490   145.0 2022-11-13
# 3905                    713    60.5 2022-11-13
# 3925                    986   152.5 2022-11-13
# 3936                   1133   133.0 2022-11-13
# 3940                    150   131.5 2022-11-13
#
#                                           Dirección     CP        lat  \
# 7             CALLE DE CIRILO AMORÓS, 82, Valencia   46004  39.466706
# 33                    CALLE DE COLÓN, 46, Valencia   46004  39.469227
# 40    GRAN VIA DEL MARQUES DEL TURIA, 80, Valencia   46005  39.468349
# 58       PLAZA MANUEL SANCHIS GUARNER, 1, Valencia   46006   39.45748
# 73       AVENIDA DE NAVARRO REVERTER, 14, Valencia   46004  39.470987
# ...                                             ...    ...        ...
# 3904                   CALLE DE COLÓN, 6, Valencia   46004  39.467302
# 3905           CALLE DEL PADRE PERERA, 5, Valencia   46006  39.462618
# 3925                  CALLE DE COLÓN, 32, Valencia   46004  39.468559
# 3936      CARRER DEL MESTRE RACIONAL, 23, Valencia   46005  39.464181
# 3940                  CARRER DE CUBA, 19, Valencia   46006  39.462015
#
#           long
# 7    -0.372928
# 33   -0.371587
# 40   -0.365033
# 58   -0.375512
# 73    -0.36659
# ...        ...
# 3904 -0.374367
# 3905 -0.371846
# 3925 -0.372568
# 3936 -0.361751
# 3940  -0.37698
#
# [408 rows x 10 columns]

# %%
columnas_eliminar = ['Número de comentarios','Precio']

prom_hotelesEix = Eixample.groupby(by='Nombre').mean('Valoración').round(decimals=1).rename(columns={'Valoración': 'Promedio de Valoración'}).drop(columnas_eliminar, axis=1).sort_values('Promedio de Valoración', ascending=False).head(5)
prom_hotelesEix
# Out:
#                                Promedio de Valoración
# Nombre
# YOURS BOUTIQUE STAY                               9.3
# CITY GARDEN BED AND BREAKFAST                     8.9
# SOHO VALENCIA                                     8.9
# ABCYOU BED&BREAKFAST                              8.7
# HOGRAFIC HOTEL BOUTIQUE                           8.7

# %%
# Los hoteles con mejor promedio en el distrito con mejor promedio
prom_hotelesEix.plot.barh()
plt.title('Hoteles con mejor promedio, en el distrito con mejor promedio')
plt.xlabel('Puntuación')
plt.ylabel('Hoteles')
# Mostrar el gráfico
plt.show()

# %%
# Crear un gráfico de violín con los datos de la columna 'Precio'
plt.figure(figsize=(10, 6))
sns.violinplot(data=precios_hoteles, y='Precio')

# Añadir etiquetas a los ejes
plt.xlabel('')
plt.ylabel('Precios')

# Añadir un título al gráfico
plt.title('Distribución de precios de los hoteles')

# Agregar etiquetas adicionales
plt.text(0.05, 0.9, f"Mínimo: {precios_hoteles['Precio'].min()}", transform=plt.gca().transAxes)
plt.text(0.05, 0.85, f"Cuartil 25%: {precios_hoteles['Precio'].quantile(0.25)}", transform=plt.gca().transAxes)
plt.text(0.05, 0.8, f"Mediana: {precios_hoteles['Precio'].median()}", transform=plt.gca().transAxes)
plt.text(0.05, 0.75, f"Cuartil 75%: {precios_hoteles['Precio'].quantile(0.75)}", transform=plt.gca().transAxes)
plt.text(0.05, 0.7, f"Máximo: {precios_hoteles['Precio'].max()}", transform=plt.gca().transAxes)

# Mostrar el gráfico
plt.show()

# %%
# Crear un gráfico de caja (box plot) con los datos de la columna 'Precio'
plt.figure(figsize=(10, 6))
sns.boxplot(data=precios_hoteles, y='Precio')

# Añadir etiquetas a los ejes
plt.xlabel('')
plt.ylabel('Precios')

# Agregar etiquetas adicionales
plt.text(0.05, 0.9, f"Mínimo: {precios_hoteles['Precio'].min()}", transform=plt.gca().transAxes)
plt.text(0.05, 0.85, f"Cuartil 25%: {precios_hoteles['Precio'].quantile(0.25)}", transform=plt.gca().transAxes)
plt.text(0.05, 0.8, f"Mediana: {precios_hoteles['Precio'].median()}", transform=plt.gca().transAxes)
plt.text(0.05, 0.75, f"Cuartil 75%: {precios_hoteles['Precio'].quantile(0.75)}", transform=plt.gca().transAxes)
plt.text(0.05, 0.7, f"Máximo: {precios_hoteles['Precio'].max()}", transform=plt.gca().transAxes)

# Añadir un título al gráfico
plt.title('Distribución de precios de los hoteles')

# Mostrar el gráfico
plt.show()

# %%
# Crear un gráfico de dispersión con los datos de la columna 'Precio' y 'Valoración', clasificado por distrito
plt.figure(figsize=(8, 6))
sns.scatterplot(data=precios_hoteles, x='Valoración', y='Precio', hue='Distrito')

# Añadir etiquetas a los ejes
plt.xlabel('Valoración')
plt.ylabel('Precio')

# Añadir un título al gráfico
plt.title('Dispersión Precios vs Valoracion, segun el Distrito')

# Mostrar el gráfico
plt.show()

# %%
# Filtrar los hoteles cuyo precio es mayor a 80
precios_hoteles[precios_hoteles['Precio'] > 80]
# Out:
#                         Nombre                      Distrito  Valoración  \
# 4           SWEET HOTEL RENASA     El Pla del Real, Valencia         8.1
# 6                  HOTEL TURIA            Campanar, Valencia         7.5
# 9      SWEET HOTEL CONTINENTAL        Ciutat Vella, Valencia         8.1
# 10     EUROSTARS REY DON JAIME      Camins al Grau, Valencia         7.9
# 12              ZENIT VALENCIA           Extramurs, Valencia         8.6
# ...                        ...                           ...         ...
# 3954           SH SUITE PALACE        Ciutat Vella, Valencia         8.5
# 3955                  LOTELITO        Ciutat Vella, Valencia         8.8
# 3956     ORIGINAL DOMINO HOUSE      Camins al Grau, Valencia         8.7
# 3957  REINA 107 BEACH BOUTIQUE  Poblados marítimos, Valencia         8.7
# 3958          OTTOH CHARM STAY        Ciutat Vella, Valencia         8.9
#
#       Número de comentarios  Precio      Fecha  \
# 4                      3441    84.0 2022-07-31
# 6                      3045    97.0 2022-07-31
# 9                      3174    86.5 2022-07-31
# 10                    11638   127.0 2022-07-31
# 12                     1863   110.0 2022-07-31
# ...                     ...     ...        ...
# 3954                    261   105.5 2022-11-13
# 3955                   1299   228.0 2022-11-13
# 3956                    725   102.0 2022-11-13
# 3957                    393   349.0 2022-11-13
# 3958                    845   394.0 2022-11-13
#
#                                               Dirección     CP        lat  \
# 4                     AVENIDA DE CATALUÑA, 5, Valencia   46010  39.480567
# 6     CARRER DEL PROFESOR BELTRÁN BÁGUENA, 2, Valencia   46009  39.480357
# 9                        CALLE DE CORREOS, 8, Valencia   46002  39.469706
# 10                       AVENIDA BALEARES, 2, Valencia   46023  39.463394
# 12            CALLE DE BAILÉN, 8, LA ROQUETA, Valencia   46007  39.466768
# ...                                                 ...    ...        ...
# 3954         PLAÇA DE MARGARITA VALLDAURA, 2, Valencia   46002  39.473334
# 3955                      CALLE DE VIRUÉS, 6, Valencia   46002  39.470981
# 3956   CALLE DE LAS ISLAS CANARIAS, 51, GRAO, Valencia   46023  39.461333
# 3957                 CARRER DE LA REINA, 107, Valencia   46011  39.468452
# 3958   CARRER DEL SANTÍSSIM, 5, CIUDAD VIEJA, Valencia   46003   39.47466
#
#           long
# 4     -0.35296
# 6    -0.389011
# 9    -0.374548
# 10   -0.356647
# 12    -0.37808
# ...        ...
# 3954 -0.374854
# 3955 -0.374681
# 3956 -0.338056
# 3957 -0.328803
# 3958  -0.37147
#
# [3063 rows x 10 columns]

# %%
# Ordenar los hoteles por valoración en orden descendente y obtener los primeros 10 hoteles
precios_hoteles.sort_values(by='Valoración', ascending=False).head(10)
# Out:
#                   Nombre                Distrito  Valoración  \
# 981   PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 3767  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 1182  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 3661  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 337   PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 2049  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 3607  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 150   PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 2430  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
# 3041  PALACIO VALLIER 5*  Ciutat Vella, Valencia         9.5
#
#       Número de comentarios  Precio      Fecha  \
# 981                     836   221.0 2023-02-12
# 3767                    836   272.0 2022-10-30
# 1182                    836   249.5 2022-11-27
# 3661                    832   374.0 2022-06-26
# 337                     836   221.0 2022-12-18
# 2049                    832   252.5 2022-07-17
# 3607                    836   374.0 2022-12-04
# 150                     796   707.5 2022-06-19
# 2430                    836   266.5 2022-09-18
# 3041                    836   275.0 2022-09-11
#
#                            Dirección     CP        lat      long
# 981   PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 3767  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 1182  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 3661  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 337   PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 2049  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 3607  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 150   PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 2430  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252
# 3041  PLAZA DE MANISES, 7, Valencia   46003  39.476753 -0.376252

# %%
# Agrupar los datos por distrito y calcular la suma de los precios por distrito
precios_por_distrito = precios_hoteles.groupby('Distrito')['Precio'].sum()

# Crear un diagrama de sectores con los datos agrupados por distrito
ax1=precios_por_distrito.plot.pie(autopct='%.1f%%',pctdistance=1.2,labeldistance=1.4,radius=1.2)


# Mostrar el gráfico
plt.show()

# %%
# Agrupar los datos por distrito y calcular el promedio de las valoraciones por distrito
valoraciones_por_distrito = precios_hoteles.groupby('Distrito')['Valoración'].mean()

# Crear un diagrama de sectores con los datos agrupados por distrito
ax=valoraciones_por_distrito.plot.pie(autopct='%.1f%%',radius=1.2,pctdistance=1.2,labeldistance=1.4)

# Mostrar el gráfico
plt.show()

# %%
# Agrupar los datos por distrito y calcular el número de hoteles por distrito
hoteles_por_distrito = precios_hoteles.groupby('Distrito')['Nombre'].count()

# Crear un diagrama de sectores con los datos agrupados por distrito
ax2=hoteles_por_distrito.plot.pie(autopct='%.1f%%',radius=1.2,pctdistance=1.2,labeldistance=1.4)

# Mostrar el gráfico
plt.show()
